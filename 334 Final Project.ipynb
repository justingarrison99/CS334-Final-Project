# %% [markdown]
# # Final Project
#
# Pulled data from:

# %%
import pandas as pd
import matplotlib 
import matplotlib.pyplot as plt
import seaborn as sns
file_name = 'seattle-crime-stats-by-police-precinct-2008-present.csv'
crime_df = pd.read_csv(file_name)
crime_df['REPORT_DATE'] = pd.to_datetime(crime_df['REPORT_DATE'])
crime_df.head(24)
# Out:
#    Police Beat           CRIME_TYPE  \
# 0           R2                 Rape
# 1           K2              Assault
# 2           M2             Homicide
# 3           C3              Robbery
# 4           E2  Motor Vehicle Theft
# 5           S3             Burglary
# 6           G3              Assault
# 7           R3             Homicide
# 8           O1                 Rape
# 9           W3             Burglary
# 10          D2             Burglary
# 11          S2  Motor Vehicle Theft
# 12          L1  Motor Vehicle Theft
# 13          U1  Motor Vehicle Theft
# 14          K3              Assault
# 15          Q3              Robbery
# 16          U1             Homicide
# 17          N2                 Rape
# 18          E2             Homicide
# 19          W2                 Rape
# 20          O3              Assault
# 21          K2              Robbery
# 22          F1        Larceny-Theft
# 23          F1             Homicide
#
# ...

# %%
f_name = 'weather_description.csv'
weather_df = pd.read_csv(f_name)
weather_df['datetime'] = pd.to_datetime(weather_df['datetime'])
weather_df.drop(weather_df.columns.difference(['datetime','Seattle']), 1, inplace=True)
weather_df = (weather_df.set_index('datetime').groupby('Seattle')
                    .resample('D').count().unstack('Seattle'))
weather_df
# Out:
#                  Seattle                                                      \
# Seattle    broken clouds drizzle few clouds fog haze heavy intensity drizzle
# datetime
# 2012-10-01           NaN     NaN        5.0 NaN  NaN                     NaN
# 2012-10-02           5.0     NaN        0.0 NaN  NaN                     NaN
# 2012-10-03           6.0     NaN        2.0 NaN  NaN                     NaN
# 2012-10-04           0.0     NaN        0.0 NaN  NaN                     NaN
# 2012-10-05           0.0     NaN        0.0 NaN  NaN                     NaN
# ...                  ...     ...        ...  ..  ...                     ...
# 2017-11-26           0.0     NaN        0.0 NaN  NaN                     NaN
# 2017-11-27           6.0     NaN        0.0 NaN  NaN                     NaN
# 2017-11-28           2.0     NaN        0.0 NaN  NaN                     NaN
# 2017-11-29           2.0     NaN        0.0 NaN  NaN                     NaN
# ...
